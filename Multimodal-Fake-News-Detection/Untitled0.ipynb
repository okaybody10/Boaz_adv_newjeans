# %%
# !python image_downloader.py multimodal_validate.tsv

# %%
import torch

print(torch.cuda.is_available())

# %%
# !python ./data/image_downloader.py ./data/multimodal_train.tsv
# Out:
# ...
#   9%|██▌                           | 48240/564000 [6:49:56<150:41:16,  1.05s/it]

# %%
# !pip install torchtext==0.11.0

# %%
# !pip install -U sentence-transformers

# %%
# !python data_preprocessing.py --test --config ./configs/sample_config.yaml

# %%
# !python run_training.py --config ./configs/sample_config.yaml

# %%
# !python image_downloader.py
